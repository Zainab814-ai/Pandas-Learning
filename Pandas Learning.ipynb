# %%
import pandas as pd
data={
    "Name":["zainab","farat"],
    "Age":[19,20]
}
df=pd.DataFrame(data)
print(df)
# Out:
#      Name  Age
# 0  zainab   19
# 1   farat   20

# %%
df=pd.read_csv("/content/boston.csv")
df.head()
pd.DataFrame(df)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df["CRIM"]
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64

# %%
df[["CRIM","ZN"]]
# Out:
#         CRIM    ZN
# 0    0.00632  18.0
# 1    0.02731   0.0
# 2    0.02729   0.0
# 3    0.03237   0.0
# 4    0.06905   0.0
# ..       ...   ...
# 501  0.06263   0.0
# 502  0.04527   0.0
# 503  0.06076   0.0
# 504  0.10959   0.0
# 505  0.04741   0.0
#
# [506 rows x 2 columns]

# %%
df.loc[0]
# Out:
# CRIM         0.00632
# ZN          18.00000
# INDUS        2.31000
# CHAS         0.00000
# NOX          0.53800
# RM           6.57500
# AGE         65.20000
# DIS          4.09000
# RAD          1.00000
# TAX        296.00000
# PTRATIO     15.30000
# B          396.90000
# LSTAT        4.98000
# MEDV        24.00000
# Name: 0, dtype: float64

# %%
df.loc[4]
# Out:
# CRIM         0.06905
# ZN           0.00000
# INDUS        2.18000
# CHAS         0.00000
# NOX          0.45800
# RM           7.14700
# AGE         54.20000
# DIS          6.06220
# RAD          3.00000
# TAX        222.00000
# PTRATIO     18.70000
# B          396.90000
# LSTAT        5.33000
# MEDV        36.20000
# Name: 4, dtype: float64

# %%
df.loc[4,"CHAS"]
# Out:
# np.int64(0)

# %%
df.loc[2,"RAD"]
# Out:
# np.int64(2)

# %%
df.loc[0:4]
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.iloc[2,2]
# Out:
# np.float64(7.07)

# %%
df.iloc[1,1]
# Out:
# np.float64(0.0)

# %%
df.iloc[1,1]
# Out:
# np.float64(0.0)

# %%
df.loc[0:4,"CHAS"]
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: CHAS, dtype: int64

# %%
df["C"]=df["CHAS"] + df["ZN"]
print(df.columns)
# Out:
# Index(['CRIM', 'CHASZN', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS',
#        'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV', 'C'],
#       dtype='object')

# %%
df.insert(1,"ZAINAB",df["CHAS"]+df["ZN"])
print(df)
# Out:
#         CRIM  ZAINAB  CHASZN    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  \
# 0    0.00632    18.0    18.0  18.0   2.31     0  0.538  6.575  65.2  4.0900
# 1    0.02731     0.0     0.0   0.0   7.07     0  0.469  6.421  78.9  4.9671
# 2    0.02729     0.0     0.0   0.0   7.07     0  0.469  7.185  61.1  4.9671
# 3    0.03237     0.0     0.0   0.0   2.18     0  0.458  6.998  45.8  6.0622
# 4    0.06905     0.0     0.0   0.0   2.18     0  0.458  7.147  54.2  6.0622
# ..       ...     ...     ...   ...    ...   ...    ...    ...   ...     ...
# 501  0.06263     0.0     0.0   0.0  11.93     0  0.573  6.593  69.1  2.4786
# 502  0.04527     0.0     0.0   0.0  11.93     0  0.573  6.120  76.7  2.2875
# 503  0.06076     0.0     0.0   0.0  11.93     0  0.573  6.976  91.0  2.1675
# 504  0.10959     0.0     0.0   0.0  11.93     0  0.573  6.794  89.3  2.3889
# 505  0.04741     0.0     0.0   0.0  11.93     0  0.573  6.030  80.8  2.5050
#
#      RAD    TAX  PTRATIO       B  LSTAT  MEDV     C
# ...

# %%
df.drop("CHASZN",axis=1,inplace=True)
print(df)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df[df["PTRATIO"]<21]
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 496  0.28960   0.0   9.69     0  0.585  5.390  72.9  2.7986    6  391.0
# 497  0.26838   0.0   9.69     0  0.585  5.794  70.6  2.8927    6  391.0
# 498  0.23912   0.0   9.69     0  0.585  6.019  65.3  2.4091    6  391.0
# 499  0.17783   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391.0
# 500  0.22438   0.0   9.69     0  0.585  6.027  79.7  2.4982    6  391.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df[df['RAD']==6]
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 111  0.10084   0.0  10.01     0  0.547  6.715  81.6  2.6775    6  432.0
# 112  0.12329   0.0  10.01     0  0.547  5.913  92.9  2.3534    6  432.0
# 113  0.22212   0.0  10.01     0  0.547  6.092  95.4  2.5480    6  432.0
# 114  0.14231   0.0  10.01     0  0.547  6.254  84.2  2.2565    6  432.0
# 115  0.17134   0.0  10.01     0  0.547  5.928  88.2  2.4631    6  432.0
# 116  0.13158   0.0  10.01     0  0.547  6.176  72.5  2.7301    6  432.0
# 117  0.15098   0.0  10.01     0  0.547  6.021  82.6  2.7474    6  432.0
# 118  0.13058   0.0  10.01     0  0.547  5.872  73.1  2.4775    6  432.0
# 119  0.14476   0.0  10.01     0  0.547  5.731  65.2  2.7592    6  432.0
# 238  0.08244  30.0   4.93     0  0.428  6.481  18.5  6.1899    6  300.0
# 239  0.09252  30.0   4.93     0  0.428  6.606  42.2  6.1899    6  300.0
# 240  0.11329  30.0   4.93     0  0.428  6.897  54.3  6.3361    6  300.0
# ...

# %%
df[(df["ZN"]==0)&(df["NOX"]==0.547) ]
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 111  0.10084  0.0  10.01     0  0.547  6.715  81.6  2.6775    6  432.0
# 112  0.12329  0.0  10.01     0  0.547  5.913  92.9  2.3534    6  432.0
# 113  0.22212  0.0  10.01     0  0.547  6.092  95.4  2.5480    6  432.0
# 114  0.14231  0.0  10.01     0  0.547  6.254  84.2  2.2565    6  432.0
# 115  0.17134  0.0  10.01     0  0.547  5.928  88.2  2.4631    6  432.0
# 116  0.13158  0.0  10.01     0  0.547  6.176  72.5  2.7301    6  432.0
# 117  0.15098  0.0  10.01     0  0.547  6.021  82.6  2.7474    6  432.0
# 118  0.13058  0.0  10.01     0  0.547  5.872  73.1  2.4775    6  432.0
# 119  0.14476  0.0  10.01     0  0.547  5.731  65.2  2.7592    6  432.0
#
#      PTRATIO       B  LSTAT  MEDV
# 111     17.8  395.59  10.16  22.8
# 112     17.8  394.95  16.21  18.8
# 113     17.8  396.90  17.09  18.7
# 114     17.8  388.74  10.45  18.5
# 115     17.8  344.91  15.76  18.3
# 116     17.8  393.30  12.04  21.2
# ...

# %%
df["CRIM"].sum()
# Out:
# np.float64(1828.4429200000004)

# %%
df["NOX"].mean()
# Out:
# np.float64(0.5546950592885376)

# %%
df["INDUS"].value_counts()
# Out:
# INDUS
# 18.10    132
# 19.58     30
# 8.14      22
# 6.20      18
# 21.89     15
#         ...
# 2.25       1
# 2.01       1
# 4.15       1
# 1.89       1
# 2.02       1
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# MINI PROJECT
# Mini-Project ()
#
# 📌 Analyze “Iris Dataset”
#
# Load dataset
#
# Show shape, info, head
#
# Filter rows where petal length > 1.5
#
# Add a new feature: sepal_ratio = sepal_length / sepal_width

# %%
from sklearn.datasets import load_iris
import pandas as pd
iris=load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
print(df)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df.shape
# Out:
# (150, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df[df["petal length (cm)"]>1.5]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 5                  5.4               3.9                1.7               0.4
# 11                 4.8               3.4                1.6               0.2
# 18                 5.7               3.8                1.7               0.3
# 20                 5.4               3.4                1.7               0.2
# 23                 5.1               3.3                1.7               0.5
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [113 rows x 4 columns]

# %%
df["sepal_ratio"]=df["sepal length (cm)"]/df["sepal width (cm)"]
print(df)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      sepal_ratio
# ...
